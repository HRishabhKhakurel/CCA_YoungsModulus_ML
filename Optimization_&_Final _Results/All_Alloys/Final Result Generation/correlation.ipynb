# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Youngs_Data_All.csv")
data = data.iloc[:,1:data.shape[1]]
features = data.iloc[:,1:data.shape[1]-1]

# %%
features
# Out:
#      Diff. Lattice Constants  Diff. Melting Point  Mixing Enthalpy  \
# 0                   0.487880           346.087653        -4.853717
# 1                   0.449913           295.639150        -9.931969
# 2                   0.381975           344.853267        -5.856117
# 3                   0.365443           180.372358        -3.714500
# 4                   0.418117           204.299411        -5.025233
# ..                       ...                  ...              ...
# 149                 0.131984           540.800564        -2.406000
# 150                 0.157731           522.696375        -0.075500
# 151                 0.141296           656.996012        -3.565120
# 152                 0.112306           569.085451        -4.589750
# 153                 0.150024           334.701368         1.397271
#
#      Lattice Constants      Lambda  Diff. in atomic radii          Omega  \
# 0             3.172259    0.845568               4.169229    5126.805332
# 1             3.028509    0.908382               3.757616    2332.647391
# 2             3.357152    0.714539               4.199646    3627.716399
# 3             2.951900  126.282311               0.302116    5808.140599
# 4             2.980337  337.314135               0.164559    3439.052841
# ..                 ...         ...                    ...            ...
# 149           3.107275    0.690133               4.086753   12347.888316
# 150           3.145625    0.744500               3.934707  387924.630551
# 151           3.149540    0.956448               3.740447   10403.899550
# 152           3.199225    0.978485               3.432162    7482.453060
# 153           3.149151    0.256956               6.494151   17565.330322
#
#      Melting Temp.  Diff. Electronegativity  Mixing Entropy  Valence electron
# 0      1693.017839                 0.094871       14.698051           8.27281
# 1      1806.304922                 0.095561       12.826063           7.88379
# 2      1685.745039                 0.100074       12.602340           8.45463
# 3      1871.750000                 0.086999       11.526293           8.25000
# 4      1891.981080                 0.100332        9.134363           8.33325
# ..             ...                      ...             ...               ...
# 149    2577.500000                 0.074498       11.526293           5.00000
# 150    2541.000000                 0.070887       11.526293           4.75000
# 151    2771.800000                 0.067112       13.381611           5.00000
# 152    2979.500000                 0.070489       11.526293           5.25000
# 153    2264.818100                 0.066339       10.836868           4.39394
#
# [154 rows x 11 columns]

# %%
correlation = features.corr()
correlation
# Out:
#                          Diff. Lattice Constants  Diff. Melting Point  \
# Diff. Lattice Constants                 1.000000            -0.438466
# Diff. Melting Point                    -0.438466             1.000000
# Mixing Enthalpy                        -0.075451            -0.330736
# Lattice Constants                       0.945173            -0.287692
# Lambda                                 -0.020599            -0.326286
# Diff. in atomic radii                  -0.086450             0.241505
# Omega                                  -0.027728            -0.054284
# Melting Temp.                          -0.543396             0.549062
# Diff. Electronegativity                -0.132186            -0.051273
# Mixing Entropy                          0.150572             0.040581
# Valence electron                        0.531652            -0.708908
#
#                          Mixing Enthalpy  Lattice Constants    Lambda  \
# Diff. Lattice Constants        -0.075451           0.945173 -0.020599
# Diff. Melting Point            -0.330736          -0.287692 -0.326286
# Mixing Enthalpy                 1.000000          -0.051011  0.089292
# Lattice Constants              -0.051011           1.000000 -0.161057
# Lambda                          0.089292          -0.161057  1.000000
# Diff. in atomic radii          -0.154032           0.045973 -0.546236
# Omega                           0.280610          -0.006119 -0.044524
# Melting Temp.                   0.355539          -0.361590 -0.137782
# Diff. Electronegativity        -0.444890          -0.212058  0.050647
# Mixing Entropy                 -0.308032           0.072305 -0.372167
# Valence electron               -0.041737           0.338549  0.293331
#
#                          Diff. in atomic radii     Omega  Melting Temp.  \
# Diff. Lattice Constants              -0.086450 -0.027728      -0.543396
# Diff. Melting Point                   0.241505 -0.054284       0.549062
# Mixing Enthalpy                      -0.154032  0.280610       0.355539
# Lattice Constants                     0.045973 -0.006119      -0.361590
# Lambda                               -0.546236 -0.044524      -0.137782
# Diff. in atomic radii                 1.000000  0.080818       0.048432
# Omega                                 0.080818  1.000000       0.112709
# Melting Temp.                         0.048432  0.112709       1.000000
# Diff. Electronegativity               0.158160 -0.131271      -0.457411
# Mixing Entropy                        0.186063 -0.081557      -0.354386
# Valence electron                     -0.391834 -0.141421      -0.758083
#
#                          Diff. Electronegativity  Mixing Entropy  \
# Diff. Lattice Constants                -0.132186        0.150572
# Diff. Melting Point                    -0.051273        0.040581
# Mixing Enthalpy                        -0.444890       -0.308032
# Lattice Constants                      -0.212058        0.072305
# Lambda                                  0.050647       -0.372167
# Diff. in atomic radii                   0.158160        0.186063
# Omega                                  -0.131271       -0.081557
# Melting Temp.                          -0.457411       -0.354386
# Diff. Electronegativity                 1.000000        0.317422
# Mixing Entropy                          0.317422        1.000000
# Valence electron                        0.256272        0.219728
#
#                          Valence electron
# Diff. Lattice Constants          0.531652
# Diff. Melting Point             -0.708908
# Mixing Enthalpy                 -0.041737
# Lattice Constants                0.338549
# Lambda                           0.293331
# Diff. in atomic radii           -0.391834
# Omega                           -0.141421
# Melting Temp.                   -0.758083
# Diff. Electronegativity          0.256272
# Mixing Entropy                   0.219728
# Valence electron                 1.000000

# %%
cor = np.array(correlation)
cor
# Out:
# array([[ 1.        , -0.43846592, -0.07545135,  0.94517319, -0.02059912,
#         -0.08645048, -0.02772809, -0.54339633, -0.13218626,  0.15057161,
#          0.5316521 ],
#        [-0.43846592,  1.        , -0.33073552, -0.28769231, -0.32628579,
#          0.24150497, -0.05428376,  0.54906153, -0.05127281,  0.04058145,
#         -0.70890777],
#        [-0.07545135, -0.33073552,  1.        , -0.05101146,  0.08929233,
#         -0.15403197,  0.28061015,  0.35553926, -0.44489006, -0.30803195,
#         -0.0417367 ],
#        [ 0.94517319, -0.28769231, -0.05101146,  1.        , -0.16105692,
#          0.04597279, -0.00611856, -0.36158975, -0.21205833,  0.07230483,
#          0.33854944],
#        [-0.02059912, -0.32628579,  0.08929233, -0.16105692,  1.        ,
#         -0.54623607, -0.04452402, -0.13778247,  0.05064678, -0.37216723,
#          0.29333094],
#        [-0.08645048,  0.24150497, -0.15403197,  0.04597279, -0.54623607,
#          1.        ,  0.08081754,  0.048432  ,  0.15815993,  0.186063  ,
#         -0.39183387],
#        [-0.02772809, -0.05428376,  0.28061015, -0.00611856, -0.04452402,
#          0.08081754,  1.        ,  0.11270938, -0.13127077, -0.08155682,
#         -0.14142096],
#        [-0.54339633,  0.54906153,  0.35553926, -0.36158975, -0.13778247,
#          0.048432  ,  0.11270938,  1.        , -0.45741133, -0.35438623,
#         -0.75808275],
#        [-0.13218626, -0.05127281, -0.44489006, -0.21205833,  0.05064678,
#          0.15815993, -0.13127077, -0.45741133,  1.        ,  0.31742171,
#          0.2562716 ],
#        [ 0.15057161,  0.04058145, -0.30803195,  0.07230483, -0.37216723,
#          0.186063  , -0.08155682, -0.35438623,  0.31742171,  1.        ,
#          0.21972789],
#        [ 0.5316521 , -0.70890777, -0.0417367 ,  0.33854944,  0.29333094,
#         -0.39183387, -0.14142096, -0.75808275,  0.2562716 ,  0.21972789,
#          1.        ]])

# %%
labels = [r'$\Delta a$',r'$\Delta T_{m}$',r'$\Delta H_{mix}$',r'$a_{m}$',r'$\lambda$',r'$\delta$',r'$\Omega$',r'$T_{m}$',r'$\Delta \chi$',r'$\Delta S_{mix}$','V.E.C']

# %%
f, ax = plt.subplots(figsize = (12,12))
sns.heatmap(cor,annot = True)
ax.set_xticklabels(labels,fontsize = 15)
ax.set_yticklabels(labels,fontsize = 15)
plt.savefig('corr_all.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
